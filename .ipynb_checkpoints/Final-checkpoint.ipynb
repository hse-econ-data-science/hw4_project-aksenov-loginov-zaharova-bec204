# %% [markdown]
# # Шаг 1. Парсинг

# %% [markdown]
# # Шаг 2. Предварительная обработка

# %% [markdown]
# 1. Сначала мы создали DataFrame на основе полученных данных:

# %%
import pandas as pd
import json


y = []
with open("data\data_combined.json", 'r', encoding='utf-8') as f:
    y = json.load(f)

a = []
for elem in (y[list(y.keys())[i]][20] for i in range(len(list(y.keys())))):
    if elem == 1:
        a.append('Без ремонта')
    elif elem == 2:
        a.append('Косметический')
    elif elem == 3:
        a.append('Евроремонт')
    elif elem == 4:
        a.append('Дизайнерский')
    else:
        a.append(0)

df = pd.DataFrame()


df['Собственник'] = list(y[list(y.keys())[i]][1] for i in range(len(list(y.keys()))))
df['Цена аренды'] = list(y[list(y.keys())[i]][0] for i in range(len(list(y.keys()))))
df['Описание'] = list(y[list(y.keys())[i]][9] for i in range(len(list(y.keys()))))
df['Минимальное время до метро, мин'] = list(y[list(y.keys())[i]][2] for i in range(len(list(y.keys()))))
df['Общая площадь, \xa0м²'] = list(y[list(y.keys())[i]][3] for i in range(len(list(y.keys()))))
df['Жилая площадь, \xa0м²'] = list(y[list(y.keys())[i]][4] for i in range(len(list(y.keys()))))
df['Площадь кухни, \xa0м²'] = list(y[list(y.keys())[i]][5] for i in range(len(list(y.keys()))))
df['Этаж квартиры'] = list(y[list(y.keys())[i]][6] for i in range(len(list(y.keys()))))
df['Этажей в доме'] = list(y[list(y.keys())[i]][7] for i in range(len(list(y.keys()))))
df['Год постройки'] = list(y[list(y.keys())[i]][8] for i in range(len(list(y.keys()))))


df['Холодильник'] = list(y[list(y.keys())[i]][10] for i in range(len(list(y.keys()))))
df['Посудомоечная машина'] = list(y[list(y.keys())[i]][11] for i in range(len(list(y.keys()))))
df['Мебель в комнатах'] = list(y[list(y.keys())[i]][13] for i in range(len(list(y.keys()))))
df['Телевизор'] = list(y[list(y.keys())[i]][14] for i in range(len(list(y.keys()))))
df['Интернет'] = list(y[list(y.keys())[i]][15] for i in range(len(list(y.keys()))))
df['Кондиционер'] = list(y[list(y.keys())[i]][16] for i in range(len(list(y.keys()))))
df['Душевая кабина'] = list(y[list(y.keys())[i]][17] for i in range(len(list(y.keys()))))
df['Ванна'] = list(y[list(y.keys())[i]][18] for i in range(len(list(y.keys()))))




df['Тип ремонта'] = a
df['Можно с детьми'] = list(y[list(y.keys())[i]][21] for i in range(len(list(y.keys()))))
df['Можно с животными'] = list(y[list(y.keys())[i]][22] for i in range(len(list(y.keys()))))
df['Полный адрес'] = list(y[list(y.keys())[i]][25] for i in range(len(list(y.keys()))))
df['Улица'] = list(y[list(y.keys())[i]][26] for i in range(len(list(y.keys()))))
df['Район'] = list(y[list(y.keys())[i]][27] for i in range(len(list(y.keys()))))
df['Рекомендованная цена'] = list(y[list(y.keys())[i]][28] for i in range(len(list(y.keys()))))
df['Залог'] = list(y[list(y.keys())[i]][29] for i in range(len(list(y.keys()))))
df['Комиссия'] = list(y[list(y.keys())[i]][30] for i in range(len(list(y.keys()))))
df['Предоплата'] = list(y[list(y.keys())[i]][31] for i in range(len(list(y.keys()))))
df['Длительность съёма'] = list(y[list(y.keys())[i]][32] for i in range(len(list(y.keys()))))
df['Возможность торга'] = list(y[list(y.keys())[i]][33] for i in range(len(list(y.keys()))))





df.head().style.hide_index()
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# Итого получили следующие колонки:

# %%
df.columns
# Out:
# Index(['Собственник', 'Цена аренды', 'Описание',
#        'Минимальное время до метро, мин', 'Общая площадь,  м²',
#        'Жилая площадь,  м²', 'Площадь кухни,  м²', 'Этаж квартиры',
#        'Этажей в доме', 'Год постройки', 'Холодильник', 'Посудомоечная машина',
#        'Мебель в комнатах', 'Телевизор', 'Интернет', 'Кондиционер',
#        'Душевая кабина', 'Ванна', 'Тип ремонта', 'Можно с детьми',
#        'Можно с животными', 'Полный адрес', 'Улица', 'Район',
#        'Рекомендованная цена', 'Залог', 'Комиссия', 'Предоплата',
#        'Длительность съёма', 'Возможность торга'],
#       dtype='object')

# %% [markdown]
# 2. Затем составили таблицу, в которой рассмотрели, сколько 0 мы получили по каждому из признаков в прцентном соотношении:

# %%
df[df == 0].count(axis=0)/df.shape[0] * 100
# Out:
# Собственник                         0.000000
# Цена аренды                         0.000000
# Описание                            0.000000
# Минимальное время до метро, мин     8.689840
# Общая площадь,  м²                  9.090909
# Жилая площадь,  м²                 32.620321
# Площадь кухни,  м²                 34.491979
# Этаж квартиры                       9.090909
# Этажей в доме                       9.090909
# Год постройки                      48.529412
# Холодильник                        11.831551
# Посудомоечная машина               28.877005
# Мебель в комнатах                  15.574866
# Телевизор                          11.363636
# Интернет                           19.585561
# Кондиционер                        18.783422
# Душевая кабина                     35.895722
# Ванна                              54.077540
# Тип ремонта                        10.561497
# Можно с детьми                     50.735294
# Можно с животными                  33.622995
# ...

# %% [markdown]
# Очевидно, что по некоторым признакам их совсем нет. А по некоторым признакам 0 может означать отсутствие какой-либо возможности или запрет. Мы решили исходить из того, что если что-то прямо не разрешено в объявлении и, как следствие, не указано в нём, то оно именно отсутсвует или запрещено. Поэтому 0 в столбцах "Возможность торга", "Предоплата", "Комиссия", "Залог", "Рекомендованная цена" мы пометили как "Отсутствует". А в столбцах "Можно с детьми" и "Можно с животными" 0 - это "Нет"

# %%
df.loc[df['Рекомендованная цена']== 0, 'Рекомендованная цена'] = 'Отсутствует'
df.loc[df['Залог']== 0, 'Залог'] = 'Отсутствует'
df.loc[df['Комиссия']== 0, 'Комиссия'] = 'Отсутствует'
df.loc[df['Длительность съёма']== 0, 'Длительность съёма'] = 'Отсутствует'
df.loc[df['Предоплата']== 0, 'Предоплата'] = 'Отсутствует'
df.loc[df['Возможность торга']== 0, 'Возможность торга'] = 'Отсутствует'
df.loc[df['Можно с животными']== 0, 'Можно с животными'] = 'Нет'
df.loc[df['Можно с животными']== 1, 'Можно с животными'] = 'Да'
df.loc[df['Можно с детьми']== 0, 'Можно с детьми'] = 'Нет'
df.loc[df['Можно с детьми']== 1, 'Можно с детьми'] = 'Да'

# %%
df.head().style.hide_index()
# Out:
# <style  type="text/css" >
# ...

# %%
# price_rec =[]
# for elem in (y[list(y.keys())[i]][28] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         price_rec.append('Отсутсвует')
#     else:
#         price_rec.append(elem)
        
# zalog = []
# for elem in (y[list(y.keys())[i]][29] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         zalog.append('Отсутсвует')
#     else:
#         zalog.append(elem)

# commission = []        
# for elem in (y[list(y.keys())[i]][30] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         commission.append('Отсутсвует')
#     else:
#         commission.append(elem)        
        
# latitude = []        
# for elem in (y[list(y.keys())[i]][32] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         latitude.append('Отсутсвует')
#     else:
#         latitude.append(elem)       
        
# prepay = []
# for elem in (y[list(y.keys())[i]][31] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         prepay.append('Отсутсвует')
#     else:
#         prepay.append(elem)
        
# chaffer = []
# for elem in (y[list(y.keys())[i]][33] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         chaffer.append('Отсутсвует')
#     else:
#         chaffer.append(elem)
# kids = []
# for elem in (y[list(y.keys())[i]][21] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         kids.append("Нет")
#     else:
#         kids.append('Да')

# pets = []
# for elem in (y[list(y.keys())[i]][22] for i in range(len(list(y.keys())))):
#     if elem == 0:
#         pets.append("Нет")
#     else:
#         pets.append('Да')      
        
        
# df['Рекомендованная цена'] = price_rec
# df['Залог'] = zalog
# df['Комиссия'] = commission
# df['Предоплата'] = prepay
# df['Длительность съёма'] = latitude
# df['Возможность торга'] = chaffer
# df['Можно с детьми'] = kids
# df['Можно с животными'] = pets

# df.head().style.hide_index()
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# Что до остальных пропусков, то нигде они не превышают 50%, а значит у нас остаётся более 500 строк с этими признаками непропущенными. Мы решили их оставить и обозначить нули как "Нет данных", потому что очевидно, что для проверки большинства возможных гипотез не понадобится смотреть на все столбцы. Следовательно, можно выдвигать и проверять гипотезы, рассматривая только строки с данными, комбинируя некоторые части таблицы и игнорируя остальные.

# %%
for elem in list(df.columns):
    df.loc[df[elem]==0, elem] = 'Нет данных'
df.sample(10)
# Out:
#             Собственник Цена аренды  \
# 1339              EVANS      240000
# 1247  Людмила Василенко       70000
# 547   Apple Real Estate      180000
# 359             Savills      300000
# 920    Verges of estate      360000
# 1152       Chase R.E.S.      150000
# 1215          АБ Риэлти       43000
# 1459            Savills      350000
# 1413     MoscowCitySale     1000000
# 11          ID 66996893      180000
#
#                                                Описание  \
# 1339  #510799 В аренду сдается квартира по адресу: К...
# 1247  Отличный вариант для семьи.\n Сдаётся 3-х комн...
# 547   Лот 77141. Владимир Родионов.\n\nБонус агенту ...
# 359   ID 35357  Предлагается трехкомнатная квартира ...
# 920   ЖК Дом на Мосфильмовской. В аренду предлагаетс...
# 1152  ЛОТ 59495 Впервые сдается 3-х к.квартира  с ев...
# 1215  В охраняемом дачном поселке сдается трехкомнат...
# 1459  ID 18105  Прекрасная 3-комнатная квартира с ди...
# ...

# %% [markdown]
# # Шаг 3. Создание новых признаков

# %%
С ходу придумываются только новостройка/относительно старое здание (нужно договориться о годе постройки),
находится ли район в центре,
сколько квартир у данного собственника

# %% [markdown]
# # Шаг 4. Визуализация

# %%
График i. код + комментарий (описание графика). Нужно выдвинуть гипотезу на основе графика.

# %% [markdown]
# # Шаг 5. Работа с pandas

# %%
Проверка гипотезы из пункта 5 с помощью группировки данных.
